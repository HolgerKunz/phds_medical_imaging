# %% [markdown]
# # Practical PHDS: Medical Imaging

# %% [markdown]
# # DICOM

# %% [markdown]
# ## Learning Activity 1: Have a look at these websites and see what they provide

# %% [markdown]
# Digital Imaging and Communications in Medicine (DICOM) is a standard for handling, storing, printing, and transmitting information in medical imaging.
#
# DICOM Datasets
#
# There’s a wealth of freely available DICOM datasets online but here’s a few that should get you started:
#
#     Osirix Datasets: Large range of human datasets acquired through a variety of imaging modalities.
#     http://www.osirix-viewer.com/resources/dicom-image-library/
#
#     Visible Human Datasets: Parts of the Visible Human project are somehow freely distributed here.
#     https://www.nlm.nih.gov/research/visible/visible_human.html
#
#     The Zubal Phantom: This website offers multiple datasets of two human males in CT and MRI.
#     http://noodle.med.yale.edu/zubal/

# %% [markdown]
# ## Learning Activity 2: Have a look at the DICOM information sources and see what DICOM-Viewers are available

# %% [markdown]
# DICOM Information Sources
#
# http://www.dclunie.com/medical-image-faq/html/part8.html#DICOMFileConvertorsAndViewers

# %% [markdown]
# # DICOM in Python

# %% [markdown]
# The pydicom package consists of pure-python code, is hosted on pypi, and can be easily installed through pip as such:

# %% [raw]
# pip install pydicom

# %%
# !pip install pydicom
# Out:
# Requirement already satisfied: pydicom in /home/nbcommon/anaconda2_501/lib/python2.7/site-packages

# %% [markdown]
# ## How do we use Dicom in Python?

# %%
import dicom

# %%
#further imports
import sys 
import glob
import numpy as np
import matplotlib.pyplot as plt  
import matplotlib.cm as cm

plt.xkcd(scale=.5, length=100, randomness=2)

# %matplotlib inline

# %% [markdown]
# # Accessing the image's meta-data

# %%
#download the files from moodle and unzip
file_path ='MR-MONO2-16-knee.dcm'

# %%
#reading the dicom file
my_dcm_file = dicom.read_file(file_path)

# %%
my_dcm_file.PatientsName #Really? Who would have thought?
# Out:
# 'Anonymized'

# %% [markdown]
# ## You can also set values by name or tag number:

# %%
my_dcm_file.PatientID = "12345"

# %% [markdown]
# # Learning Activity 3: Change the patient's name to your own last name

# %%
my_dcm_file.PatientsName = "NameUCLStudent"

# %%
my_dcm_file
# Out:
# (0008, 0000) Group Length                        UL: 414
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113619.2.1.2.139348932.2.9.602503126
# (0008, 0020) Study Date                          DA: '1989.02.03'
# (0008, 0021) Series Date                         DA: '1989.02.03'
# (0008, 0023) Content Date                        DA: '1989.02.03'
# (0008, 0030) Study Time                          TM: '09:26:18'
# (0008, 0031) Series Time                         TM: '09:58:19'
# (0008, 0033) Content Time                        TM: '09:58:46'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0080) Institution Name                    LO: 'THOMAS JEFF UNIVHOSPITAL MRI'
# (0008, 0090) Referring Physician's Name          PN: 'Anonymized'
# (0008, 1010) Station Name                        SH: 'FOR.IC0'
# (0008, 1030) Study Description                   LO: 'KNEE'
# (0008, 103e) Series Description                  LO: 'SAG 3D'
# (0008, 1060) Name of Physician(s) Reading Study  PN: 'Anonymized'
# (0008, 1070) Operators' Name                     PN: 'Anonymized'
# (0008, 1090) Manufacturer's Model Name           LO: 'GENESIS_SIGNA'
# (0010, 0000) Group Length                        UL: 18
# (0010, 0010) Patient's Name                      PN: 'NameUCLStudent'
# (0010, 0020) Patient ID                          LO: '12345'
# (0018, 0000) Group Length                        UL: 368
# (0018, 0010) Contrast/Bolus Agent                LO: 'NONE'
# (0018, 0020) Scanning Sequence                   CS: 'GR'
# (0018, 0021) Sequence Variant                    CS: 'GR'
# (0018, 0022) Scan Options                        CS: 'GRAPH_GEMS'
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: '3.000000'
# (0018, 0080) Repetition Time                     DS: '33.000000'
# (0018, 0081) Echo Time                           DS: '15.000000'
# (0018, 0083) Number of Averages                  DS: '1.000000'
# (0018, 0084) Imaging Frequency                   DS: '0.0000000000'
# (0018, 0085) Imaged Nucleus                      SH: 'H1'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: '15000'
# (0018, 0088) Spacing Between Slices              DS: '3.000000'
# (0018, 0091) Echo Train Length                   IS: '0'
# (0018, 0093) Percent Sampling                    DS: '100.000000'
# (0018, 0094) Percent Phase Field of View         DS: '100.000000'
# (0018, 1062) Nominal Interval                    IS: '33000'
# (0018, 1088) Heart Rate                          IS: '0'
# (0018, 1090) Cardiac Number of Images            IS: '0'
# (0018, 1094) Trigger Window                      IS: '10'
# (0018, 1100) Reconstruction Diameter             DS: '160.0000000000'
# (0018, 1314) Flip Angle                          DS: '30'
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: '0.009903'
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0020, 0000) Group Length                        UL: 304
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.2.1.2.139348932.602501178
# (0020, 000e) Series Instance UID                 UI: 1.2.840.113619.2.1.2.139348932.2.602503099
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '0'
# (0020, 0013) Instance Number                     IS: '9'
# (0020, 0032) Image Position (Patient)            DS: ['16.500000', '-80.000000', ' 84.726562']
# (0020, 0037) Image Orientation (Patient)         DS: ['0.000000', '1.000000', '0.000000', '0.000000', '0.000000', ' -1.000000']
# (0020, 0052) Frame of Reference UID              UI: 1.2.840.113619.2.1.2.139348932.0
# (0020, 1040) Position Reference Indicator        LO: 'KN'
# (0020, 1041) Slice Location                      DS: '-16.5000000000'
# (0028, 0000) Group Length                        UL: 132
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: ['0.625', '0.625']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 1050) Window Center                       DS: '1095'
# (0028, 1051) Window Width                        DS: '84'
# (7fe0, 0000) Group Length                        UL: 131080
# (7fe0, 0010) Pixel Data                          OB or OW: Array of 131072 bytes

# %% [markdown]
# # What if we want to work with an array?

# %%
#transfer into an array with grey values
my_dcm_array = my_dcm_file.pixel_array
my_dcm_array
# Out:
# array([[1024, 1024, 1024, ..., 1025, 1024, 1024],
#        [1024, 1024, 1024, ..., 1025, 1024, 1024],
#        [1031, 1033, 1029, ..., 1040, 1034, 1028],
#        ...,
#        [1028, 1027, 1027, ..., 1061, 1025, 1029],
#        [1031, 1030, 1030, ..., 1067, 1026, 1030],
#        [1024, 1024, 1024, ..., 1026, 1024, 1024]], dtype=int16)

# %% [markdown]
# # Visualize

# %%
plt.figure(figsize=(8,6))
plt.imshow(my_dcm_array, cmap=plt.cm.gray)
plt.colorbar()
# Out:
# /home/nbuser/anaconda2_501/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'xkcd', u'Humor Sans', u'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Histogram of grey values

# %%
plt.figure(figsize=(8,6))
plt.hist(my_dcm_array.ravel(), bins=32, log=True);

# %% [markdown]
# # Simple binary image processing

# %%
bgmean = my_dcm_array[:,:].mean()
print (bgmean)
# Out:
# 1085.70285034

# %%
#do some operations
brainmask = my_dcm_array > bgmean
plt.figure(figsize=(8,6))
plt.imshow(brainmask, cmap = cm.Greys_r);

# %% [markdown]
# ## Add some random noise

# %%
#add some noise

my_dcm_array[np.random.randint(0, my_dcm_array.shape[0], int(0.05 * my_dcm_array.size)), np.random.randint(0, my_dcm_array.shape[1], int(0.05 * my_dcm_array.size))] = my_dcm_array.min()
my_dcm_array[np.random.randint(0, my_dcm_array.shape[0], int(0.05 * my_dcm_array.size)), np.random.randint(0, my_dcm_array.shape[1], int(0.05 * my_dcm_array.size))] = my_dcm_array.max()
plt.figure(figsize=(8,6))
plt.imshow(my_dcm_array, cmap = cm.Greys_r);

# %% [markdown]
# # --- MULTIPLE SLICES ---

# %%
#importing packages we’ll need:
import dicom
import numpy
from matplotlib import pyplot, cm

# %%
lstFilesDCM = []  # create an empty list
for i in range(0,176):
    lstFilesDCM.append("MR000%0003d.dcm" % i) #loead all head-files

# %%
ds = dicom.read_file(lstFilesDCM[0])

# %%
#let us look into the header
ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
# (0008, 0012) Instance Creation Date              DA: '20111110'
# (0008, 0013) Instance Creation Time              TM: '094123.531000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.2.30.25591.2011111009411414857727859
# (0008, 0020) Study Date                          DA: '20111110'
# (0008, 0021) Series Date                         DA: '20111110'
# (0008, 0022) Acquisition Date                    DA: '20111110'
# (0008, 0023) Content Date                        DA: '20111110'
# (0008, 0030) Study Time                          TM: '093416.265000'
# (0008, 0031) Series Time                         TM: '094123.531000'
# (0008, 0032) Acquisition Time                    TM: '093522.335000'
# (0008, 0033) Content Time                        TM: '094123.531000'
# (0008, 0050) Accession Number                    SH: '19078400556130'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'MRI Bahnhofplatz'
# (0008, 0081) Institution Address                 ST: 'Bahnhofsplatz 3,Zuerich/5EB7E0/,Zuerich,CH,ZIP'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'HB-MRC'
# (0008, 1030) Study Description                   LO: 'Sch\xe4del - Neuro^Orbita'
# (0008, 103e) Series Description                  LO: 't2_spc_flair_irprep_sag_p2_iso'
# (0008, 1040) Institutional Department Name       LO: 'MR3_HB'
# (0008, 1048) Physician(s) of Record              PN: 'StTo'
# (0008, 1050) Performing Physician's Name         PN: 'StTo'
# (0008, 1090) Manufacturer's Model Name           LO: 'Avanto'
# (0008, 1110)  Referenced Study Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.124.113532.30.20265.59073.20111107.74456.11664418
#    ---------
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.30.25591.2011111009344480919327734
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.30.25591.2011111009344224342027730
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.2.30.25591.2011111009343968676227726
#    ---------
# (0010, 0010) Patient's Name                      PN: 'Adamos^Kyriacon'
# (0010, 0020) Patient ID                          LO: '556130'
# (0010, 0021) Issuer of Patient ID                LO: 'PrimaryDomain'
# (0010, 0030) Patient's Birth Date                DA: '19870113'
# (0010, 0032) Patient's Birth Time                TM: '000000.000000'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '024Y'
# (0010, 1030) Patient's Weight                    DS: '88'
# (0010, 1040) Patient's Address                   LO: 'Spitalgasse 9^^Z\xfcrich^CH^8001^'
# (0018, 0020) Scanning Sequence                   CS: ['SE', 'IR']
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'MP']
# (0018, 0022) Scan Options                        CS: ['IR', 'PFP']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: '*spcir3d1_274ns'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: '1'
# (0018, 0080) Repetition Time                     DS: '5000'
# (0018, 0081) Echo Time                           DS: '335'
# (0018, 0082) Inversion Time                      DS: '1800'
# (0018, 0083) Number of Averages                  DS: '1'
# (0018, 0084) Imaging Frequency                   DS: '63.667864'
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: '1'
# (0018, 0087) Magnetic Field Strength             DS: '1.5'
# (0018, 0089) Number of Phase Encoding Steps      IS: '204'
# (0018, 0091) Echo Train Length                   IS: '137'
# (0018, 0093) Percent Sampling                    DS: '97.6563'
# (0018, 0094) Percent Phase Field of View         DS: '100'
# (0018, 0095) Pixel Bandwidth                     DS: '592'
# (0018, 1000) Device Serial Number                LO: '25591'
# (0018, 1020) Software Version(s)                 LO: 'syngo MR B17'
# (0018, 1030) Protocol Name                       LO: 't2_spc_flair_irprep_sag_p2_iso'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [0, 256, 250, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: '120'
# (0018, 1315) Variable Flip Angle Flag            CS: 'Y'
# (0018, 1316) SAR                                 DS: '0.0581332283704'
# (0018, 1318) dB/dt                               DS: '0'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0019, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0019, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0019, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0019, 100b) [SliceMeasurementDuration]          DS: '347220'
# (0019, 100f) [GradientMode]                      SH: 'Fast'
# (0019, 1011) [FlowCompensation]                  SH: 'No'
# (0019, 1012) [TablePositionOrigin]               SL: [0, 0, -994]
# (0019, 1013) [ImaAbsTablePosition]               SL: [0, 0, -994]
# (0019, 1014) [ImaRelTablePosition]               IS: ['0', '0', '0']
# (0019, 1015) [SlicePosition_PCS]                 FD: [-87.5, -139.8433733, 116.90361404]
# (0019, 1017) [SliceResolution]                   DS: '0.795455'
# (0019, 1018) [RealDwellTime]                     IS: '3300'
# (0020, 000d) Study Instance UID                  UI: 1.2.124.113532.30.20265.59073.20111107.74456.11664418
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.2.30.25591.2011111009411419957127863.0.0.0
# (0020, 0010) Study ID                            SH: '19078400556130'
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: ['-87.5', '-139.84337329865', '116.90361404419']
# (0020, 0037) Image Orientation (Patient)         DS: ['0', '1', '0', '0', '0', '-1']
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.2.30.25591.1.20111110093416406.0.0.0
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '-87.5'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: ['0.9765625', '0.9765625']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 21
# (0028, 1050) Window Center                       DS: '10'
# (0028, 1051) Window Width                        DS: '21'
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER2'
# (0029, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0029, 1009) [CSA Image Header Version]          LO: '20111110'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 9572 bytes
# (0029, 1018) [CSA Series Header Type]            CS: 'MR'
# (0029, 1019) [CSA Series Header Version]         LO: '20111110'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 66728 bytes
# (0029, 1160) [Series Workflow Status]            LO: 'com'
# (0032, 000a) Study Status ID                     CS: 'SCHEDULED'
# (0032, 1032) Requesting Physician                PN: 'StTo'
# (0032, 1033) Requesting Service                  LO: 'UNKNOWN'
# (0032, 1060) Requested Procedure Description     LO: 'MRI Orbita'
# (0040, 0244) Performed Procedure Step Start Date DA: '20111110'
# (0040, 0245) Performed Procedure Step Start Time TM: '093416.343000'
# (0040, 0253) Performed Procedure Step ID         SH: '19078400556130'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MRI Orbita'
# (0040, 0275)  Request Attributes Sequence   1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'MRI Orbita'
#    (0040, 0009) Scheduled Procedure Step ID         SH: '19078400556130'
#    (0040, 1001) Requested Procedure ID              SH: '19078400556130'
#    ---------
# (0051, 0010) Private Creator                     LO: 'SIEMENS MR HEADER'
# (0051, 1008) [CSA Image Header Type]             CS: 'IMAGE NUM 4'
# (0051, 1009) [CSA Image Header Version ??]       LO: '1.0'
# (0051, 100a) [Unknown]                           LO: 'TA 05:47'
# (0051, 100b) [AcquisitionMatrixText]             LO: '250p*256'
# (0051, 100c) [Unknown]                           LO: 'FoV 250*250'
# (0051, 100d) [Unknown]                           SH: 'SP R87.5'
# (0051, 100e) [Unknown]                           LO: 'Sag'
# (0051, 100f) [CoilString]                        LO: 'C:HEA;HEP'
# (0051, 1011) [PATModeText]                       LO: 'p2'
# (0051, 1012) [Unknown]                           SH: 'TP 0'
# (0051, 1013) [PositivePCSDirections]             SH: '+LPH'
# (0051, 1015) [Unknown]                           SH: 'R'
# (0051, 1016) [Unknown]                           LO: 'p2 M/ND/NORM'
# (0051, 1017) [Unknown]                           SH: 'SL 1.0i'
# (0051, 1019) [Unknown]                           LO: 'A1/IR/PFP'
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 bytes

# %%
# Get ref file
RefDs = dicom.read_file(lstFilesDCM[0])

# Load dimensions based on the number of rows, columns, and slices (along the Z axis)
ConstPixelDims = (int(RefDs.Rows), int(RefDs.Columns), len(lstFilesDCM))

# Load spacing values (in mm)
ConstPixelSpacing = (float(RefDs.PixelSpacing[0]), float(RefDs.PixelSpacing[1]), float(RefDs.SliceThickness))

# %%
x = numpy.arange(0.0, (ConstPixelDims[0]+1)*ConstPixelSpacing[0], ConstPixelSpacing[0])
y = numpy.arange(0.0, (ConstPixelDims[1]+1)*ConstPixelSpacing[1], ConstPixelSpacing[1])
z = numpy.arange(0.0, (ConstPixelDims[2]+1)*ConstPixelSpacing[2], ConstPixelSpacing[2])

# %%
# The array is sized based on 'ConstPixelDims'
ArrayDicom = numpy.zeros(ConstPixelDims, dtype=RefDs.pixel_array.dtype)

# loop through all the DICOM files
for filenameDCM in lstFilesDCM:
    # read the file
    ds = dicom.read_file(filenameDCM)
    # store the raw image data
    ArrayDicom[:, :, lstFilesDCM.index(filenameDCM)] = ds.pixel_array

# %%
#and plotting
pyplot.figure(dpi=100)
pyplot.axes().set_aspect('equal', 'datalim')
pyplot.set_cmap(pyplot.gray())
pyplot.pcolormesh(x, y, numpy.flipud(ArrayDicom[:, :, 80])) # slice 81

# %% [markdown]
# # Learning Activity 4: Plot slice 61

# %%
#and plotting
pyplot.figure(dpi=100)
pyplot.axes().set_aspect('equal', 'datalim')
pyplot.set_cmap(pyplot.gray())
pyplot.pcolormesh(x, y, numpy.flipud(ArrayDicom[:, :, 60]))

# %%
pyplot.figure(dpi=120)
pyplot.axes().set_aspect('equal', 'datalim')
pyplot.set_cmap(pyplot.gray())

pyplot.pcolormesh(x, z, numpy.flipud(numpy.rot90(ArrayDicom[:, 115, :])))

# %% [markdown]
# # Reading DICOM through Simple ITK

# %% [markdown]
# Look at the following websites for further instructions:
#
# http://nbviewer.jupyter.org/github/SimpleITK/SimpleITK-Notebooks/blob/master/01_Image_Basics.ipynb
#
# https://itk.org/Wiki/SimpleITK/GettingStarted
#
# https://itk.org/

# %% [raw]
# pip install SimpleITK

# %%
# !pip install SimpleITK
# Out:
# Requirement already satisfied: SimpleITK in /home/nbcommon/anaconda2_501/lib/python2.7/site-packages

# %% [markdown]
# # Imports

# %%
import os
import numpy
import SimpleITK
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Helper-Functions
#
# plot a 2D SimpleITK image with a grayscale colormap and accompanying axes

# %%
def sitk_show(img, title=None, margin=0.05, dpi=40 ):
    nda = SimpleITK.GetArrayFromImage(img)
    spacing = img.GetSpacing()
    figsize = (1 + margin) * nda.shape[0] / dpi, (1 + margin) * nda.shape[1] / dpi
    extent = (0, nda.shape[1]*spacing[1], nda.shape[0]*spacing[0], 0)
    fig = plt.figure(figsize=figsize, dpi=dpi)
    ax = fig.add_axes([margin, margin, 1 - 2*margin, 1 - 2*margin])

    plt.set_cmap("gray")
    ax.imshow(nda,extent=extent,interpolation=None)
    
    if title:
        plt.title(title)
    
    plt.show()

# %% [markdown]
# # Options

# %%
# Directory where the DICOM files are being stored (in this
# case the 'Head' folder). 
pathDicom = '.'

# Z slice of the DICOM files to process. In the interest of
# simplicity, segmentation will be limited to a single 2D
# image but all processes are entirely applicable to the 3D image
idxSlice = 50

# int labels to assign to the segmented white and gray matter.
# These need to be different integers but their values themselves
# don't matter
labelWhiteMatter = 1
labelGrayMatter = 2

# %% [markdown]
# # DICOM Input
#
# Load and read-in the DICOM files

# %%
reader = SimpleITK.ImageSeriesReader()
filenamesDICOM = lstFilesDCM # reader.GetGDCMSeriesFileNames(pathDicom)
reader.SetFileNames(filenamesDICOM)
imgOriginal = reader.Execute()

# %% [markdown]
# Limit image to a single 2D slice

# %%
imgOriginal = imgOriginal[:,:,idxSlice]

# %%
sitk_show(imgOriginal)

# %% [markdown]
# # Learning Activity 5: Load Chest-File with SimpleITK (use different variables)

# %%
# solution for chest
filenamesDICOM= ['CHEST_CR-MONO1-10-chest.dcm']

reader = SimpleITK.ImageSeriesReader()
reader.SetFileNames(filenamesDICOM)
imgChest = reader.Execute()

# %%
filenamesDICOM
# Out:
# ['CHEST_CR-MONO1-10-chest.dcm']

# %%
len(imgChest)
# Out:
# 193600

# %%
#only one slice, we know it
imgChest = imgChest[:,:,0]
sitk_show(imgChest)

# %% [markdown]
# # Smoothing
#
# Apply a curvature-flow filter to smoothen the image (get rid of image noise)

# %%
imgSmooth = SimpleITK.CurvatureFlow(image1=imgOriginal,
                                    timeStep=0.125,
                                    numberOfIterations=5)

# blurFilter = SimpleITK.CurvatureFlowImageFilter()
# blurFilter.SetNumberOfIterations(5)
# blurFilter.SetTimeStep(0.125)
# imgSmooth = blurFilter.Execute(imgOriginal)

sitk_show(imgSmooth)

# %% [markdown]
# # Learning Activity 6: Play with the filter

# %%
imgSmooth = SimpleITK.CurvatureFlow(image1=imgOriginal,
                                    timeStep=0.125,
                                    numberOfIterations=50)
sitk_show(imgSmooth)

# %% [markdown]
# # Segmentation with the ConnectedThreshold filter
#
# Initial segmentation of white matter

# %%
lstSeeds = [(150,75)]

imgWhiteMatter = SimpleITK.ConnectedThreshold(image1=imgSmooth, 
                                              seedList=lstSeeds, 
                                              lower=130, 
                                              upper=190,
                                              replaceValue=labelWhiteMatter)

# %% [markdown]
# # Visualization with label overlay

# %%
# Rescale 'imgSmooth' and cast it to an integer type to match that of 'imgWhiteMatter'
imgSmoothInt = SimpleITK.Cast(SimpleITK.RescaleIntensity(imgSmooth), imgWhiteMatter.GetPixelID())

# Use 'LabelOverlay' to overlay 'imgSmooth' and 'imgWhiteMatter'
sitk_show(SimpleITK.LabelOverlay(imgSmoothInt, imgWhiteMatter))

# %%
#Fill holes in the white matter
imgWhiteMatterNoHoles = SimpleITK.VotingBinaryHoleFilling(image1=imgWhiteMatter,
                                                          radius=[2]*3,
                                                          majorityThreshold=1,
                                                          backgroundValue=0,
                                                          foregroundValue=labelWhiteMatter)

sitk_show(SimpleITK.LabelOverlay(imgSmoothInt, imgWhiteMatterNoHoles))

# %% [markdown]
# ## Segmentation & hole-filling of gray matter

# %%
lstSeeds = [(119, 83), (198, 80), (185, 102), (164, 43)]

imgGrayMatter = SimpleITK.ConnectedThreshold(image1=imgSmooth, 
                                             seedList=lstSeeds, 
                                             lower=150, 
                                             upper=270,
                                             replaceValue=labelGrayMatter)

imgGrayMatterNoHoles = SimpleITK.VotingBinaryHoleFilling(image1=imgGrayMatter,
                                                         radius=[2]*3,
                                                         majorityThreshold=1,
                                                         backgroundValue=0,
                                                         foregroundValue=labelGrayMatter)

sitk_show(SimpleITK.LabelOverlay(imgSmoothInt, imgGrayMatterNoHoles))

# %%
#Bitwire OR combination of the white matter and gray matter labels
imgLabels = imgWhiteMatterNoHoles | imgGrayMatterNoHoles


sitk_show(SimpleITK.LabelOverlay(imgSmoothInt, imgLabels))

# %%
#Assignment of common areas to the gray matter
imgMask= imgWhiteMatterNoHoles/labelWhiteMatter * imgGrayMatterNoHoles/labelGrayMatter
imgWhiteMatterNoHoles -= imgMask*labelWhiteMatter

imgLabels = imgWhiteMatterNoHoles + imgGrayMatterNoHoles

sitk_show(SimpleITK.LabelOverlay(imgSmoothInt, imgLabels))

# %%
sitk_show(SimpleITK.LabelOverlay(imgSmoothInt, SimpleITK.LabelContour(imgLabels)))

# %% [markdown]
# Thank you for your contribution. Have a nice day!
